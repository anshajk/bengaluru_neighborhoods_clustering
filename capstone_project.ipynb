# %% [markdown]
# <a href="https://colab.research.google.com/github/fulcrum3/IBM_Capstone_Project/blob/master/capstone_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone Project
# This project aims to perform a clustering analysis on the neighbourhoods of Bengaluru

# %% [markdown]
# ## Importing Libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import re
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans

# %% [markdown]
# ## Scraping data from web with beautiful soup

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Bangalore').text
soup = BeautifulSoup(source, 'lxml')
tables = soup.findAll('table')
dfs = []
for idx, table in enumerate(tables): 
  if(idx) <= 7:
    table_rows = table.find_all('tr')
    l = []
    for tr in table_rows:
        td = tr.find_all('td')
        row = [tr.text for tr in td]
        l.append(row)
    neighbourhoods = pd.DataFrame(l, columns=["Neighbourhood", "Image_link", "Inforamtion"])
    neighbourhoods = neighbourhoods.replace('\n','', regex=True)
    neighbourhoods = neighbourhoods.drop(neighbourhoods.index[0])
    dfs.append(neighbourhoods)

# %%
headings = soup.findAll('span', class_ = 'mw-headline')
regions = [heading.text for heading in headings]
regions = regions[0:8]
print('The regions in Bangalore are:', regions)
# Out:
# The regions in Bangalore are: ['Central', 'Eastern', 'North-Eastern', 'Northern', 'South-Eastern', 'Southern', 'Southern suburbs', 'Western']

# %%
neighbourhood_data = pd.DataFrame()
for region, neighbourhood in zip(regions, dfs):
  _ = pd.DataFrame({ 'Region' : region, 'Neighbourhood' : neighbourhood['Neighbourhood']})
  neighbourhood_data = neighbourhood_data.append(_,ignore_index = True)
neighbourhood_data['Neighbourhood'] = neighbourhood_data['Neighbourhood'] + ', Bengaluru'
neighbourhood_data.sample(5)
# Out:
#            Region                 Neighbourhood
# 3         Central  Jeevanbheemanagar, Bengaluru
# 16        Eastern       Marathahalli, Bengaluru
# 26       Northern             Hebbal, Bengaluru
# 20  North-Eastern         HBR Layout, Bengaluru
# 29       Northern             Peenya, Bengaluru

# %% [markdown]
# ## Geolocator for coordinates
# The geolocator library is used for obtain the coordinates for a particular address.

# %%
geolocator = Nominatim(user_agent="bengaluru_explorer")
latitudes = []
longitudes = []
for neighbourhood in neighbourhood_data['Neighbourhood']:
  location = geolocator.geocode(neighbourhood)
  try:
    latitude = location.latitude
    longitude = location.longitude
    print('The geograpical coordinate of {} are {}, {}.'.format(neighbourhood, latitude, longitude))
  except:
    neighbourhood_modified = re.sub('Bengaluru','Bangalore',neighbourhood)
    location = geolocator.geocode(neighbourhood_modified)
    print('Modified Neighbourhood -->', neighbourhood_modified)
    try:
      latitude = location.latitude
      longitude = location.longitude
      print('The geograpical coordinate of {} are {}, {}.'.format(neighbourhood_modified, latitude, longitude))
    except:
      latitude = -1
      longitude = -1
      print("We couldn't obtain the corrdinates for {}.".format(neighbourhood))
  latitudes.append(latitude)
  longitudes.append(longitude)

neighbourhood_data['Latitude'] = latitudes
neighbourhood_data['Longitude'] = longitudes
# Out:
# The geograpical coordinate of Cantonment area, Bengaluru are 8.46810875, -13.2505252481029.
# The geograpical coordinate of Domlur, Bengaluru are 12.9624669, 77.6381958.
# The geograpical coordinate of Indiranagar, Bengaluru are 12.9732913, 77.6404672.
# Modified Neighbourhood --> Jeevanbheemanagar, Bangalore
# We couldn't obtain the corrdinates for Jeevanbheemanagar, Bengaluru.
# The geograpical coordinate of Malleswaram, Bengaluru are 13.0163411, 77.5586641823841.
# The geograpical coordinate of Pete area, Bengaluru are 48.4373068, -124.099707.
# The geograpical coordinate of Sadashivanagar, Bengaluru are 13.0077079, 77.5795893.
# The geograpical coordinate of Seshadripuram, Bengaluru are 12.9931876, 77.5753419.
# The geograpical coordinate of Shivajinagar, Bengaluru are 12.986391, 77.6075416.
# The geograpical coordinate of Ulsoor, Bengaluru are 12.9778793, 77.6246697.
# The geograpical coordinate of Vasanth Nagar, Bengaluru are 12.98872125, 77.5851687760182.
# The geograpical coordinate of Bellandur, Bengaluru are 12.9791198, 77.5912997.
# The geograpical coordinate of CV Raman Nagar, Bengaluru are 17.2510682, 80.1651978.
# The geograpical coordinate of Hoodi, Bengaluru are 12.9919033, 77.7162015.
# The geograpical coordinate of Krishnarajapuram, Bengaluru are 13.007516, 77.695935.
# The geograpical coordinate of Mahadevapura, Bengaluru are 12.9934976, 77.6924156.
# The geograpical coordinate of Marathahalli, Bengaluru are 12.9552572, 77.6984163.
# The geograpical coordinate of Varthur, Bengaluru are 12.9406152, 77.7469937.
# The geograpical coordinate of Whitefield, Bengaluru are 12.9696365, 77.7497448.
# The geograpical coordinate of Banaswadi, Bengaluru are 13.0141618, 77.6518539.
# The geograpical coordinate of HBR Layout, Bengaluru are 13.0358698, 77.6323597.
# The geograpical coordinate of Horamavu, Bengaluru are 13.0273312, 77.6601508.
# The geograpical coordinate of Kalyan Nagar, Bengaluru are 13.0221416, 77.6403368.
# The geograpical coordinate of Kammanahalli, Bengaluru are 13.00796435, 77.6366701521896.
# The geograpical coordinate of Lingarajapuram, Bengaluru are 13.0117678, 77.6278288.
# The geograpical coordinate of Ramamurthy Nagar, Bengaluru are 13.0120218, 77.6777817.
# The geograpical coordinate of Hebbal, Bengaluru are 13.0382184, 77.5919.
# The geograpical coordinate of Jalahalli, Bengaluru are 13.0464531, 77.5483803.
# The geograpical coordinate of Mathikere, Bengaluru are 13.0328884, 77.557374.
# The geograpical coordinate of Peenya, Bengaluru are 13.0329419, 77.5273253.
# Modified Neighbourhood --> R. T. Nagar, Bangalore
# We couldn't obtain the corrdinates for R. T. Nagar, Bengaluru.
# The geograpical coordinate of Vidyaranyapura, Bengaluru are 13.0766407, 77.5577315.
# The geograpical coordinate of Yelahanka, Bengaluru are 13.1006982, 77.5963454.
# The geograpical coordinate of Yeshwanthpur, Bengaluru are 13.0214, 77.5518295.
# The geograpical coordinate of Bommanahalli, Bengaluru are 12.9089453, 77.6239038.
# The geograpical coordinate of Bommasandra, Bengaluru are 12.8162443, 77.6916113.
# The geograpical coordinate of BTM Layout, Bengaluru are 12.9151772, 77.6102821.
# The geograpical coordinate of Electronic City, Bengaluru are 12.9791198, 77.5912997.
# The geograpical coordinate of HSR Layout, Bengaluru are 12.9116225, 77.6388622.
# The geograpical coordinate of Koramangala, Bengaluru are 12.9340114, 77.6222304.
# The geograpical coordinate of Madiwala, Bengaluru are 12.9212269, 77.6179508.
# The geograpical coordinate of Banashankari, Bengaluru are 12.9152208, 77.573598.
# The geograpical coordinate of Basavanagudi, Bengaluru are 12.9417261, 77.5755021.
# The geograpical coordinate of Girinagar, Bengaluru are 12.9401439, 77.5444995.
# The geograpical coordinate of J. P. Nagar, Bengaluru are 12.9094922, 77.5967385573177.
# The geograpical coordinate of Jayanagar, Bengaluru are 12.9292731, 77.5824229.
# The geograpical coordinate of Kumaraswamy Layout, Bengaluru are 12.9068169, 77.5635247362134.
# The geograpical coordinate of Padmanabhanagar, Bengaluru are 12.9181602, 77.5576735553506.
# The geograpical coordinate of Uttarahalli, Bengaluru are 12.9055682, 77.5455438.
# The geograpical coordinate of Anjanapura, Bengaluru are 12.8580811, 77.5580713.
# The geograpical coordinate of Arekere, Bengaluru are 12.87847015, 77.6041791138253.
# The geograpical coordinate of Begur, Bengaluru are 12.8633887, 77.613011205039.
# The geograpical coordinate of Gottigere, Bengaluru are 12.8565317, 77.5877237.
# The geograpical coordinate of Hulimavu, Bengaluru are 12.8773486, 77.6028031.
# The geograpical coordinate of Kothnur, Bengaluru are 12.8742546, 77.5837252.
# The geograpical coordinate of Basaveshwaranagar, Bengaluru are 12.986475, 77.5385709.
# The geograpical coordinate of Kamakshipalya, Bengaluru are 12.9823617, 77.5226376.
# The geograpical coordinate of Kengeri, Bengaluru are 12.9199402, 77.4833485.
# The geograpical coordinate of Mahalakshmi Layout, Bengaluru are 13.0119095, 77.5438333.
# The geograpical coordinate of Nagarbhavi, Bengaluru are 12.9651008, 77.5078635.
# The geograpical coordinate of Nandini Layout, Bengaluru are 13.0104064, 77.5378032.
# The geograpical coordinate of Nayandahalli, Bengaluru are 12.943655, 77.5268791.
# The geograpical coordinate of Rajajinagar, Bengaluru are 12.9882338, 77.554883.
# The geograpical coordinate of Rajarajeshwari Nagar, Bengaluru are 12.9274278, 77.5153722.
# The geograpical coordinate of Vijayanagar, Bengaluru are 12.9718886, 77.5457888388713.

# %% [markdown]
# ## Filtering for correct coordinates
# The latitude and longitude values of Bengaluru lie within a given set of values. Hence filtering only the possible values of coordinates for the city of Bengaluru

# %%
location_issue = neighbourhood_data[~((neighbourhood_data['Latitude'] > 12) & 
                                      (neighbourhood_data['Latitude'] < 14) & 
                                      (neighbourhood_data['Longitude'] > 77) & 
                                      (neighbourhood_data['Longitude'] < 78))]

neighbourhood_data = neighbourhood_data[(neighbourhood_data['Latitude'] > 12) & 
                                        (neighbourhood_data['Latitude'] < 14) & 
                                        (neighbourhood_data['Longitude'] > 77) & 
                                        (neighbourhood_data['Longitude'] < 78)]

neighbourhood_data = neighbourhood_data.reset_index()
print(f"""The coordinates for these {len(location_issue)} neighbourhoods: 
{location_issue['Neighbourhood'].tolist()} 
couldn't be obtained. 
Hence I've removed them from analysis""")
print('The final shape of neighbourhood data is', neighbourhood_data.shape)
# Out:
# The coordinates for these 5 neighbourhoods:
# ['Cantonment area, Bengaluru', 'Jeevanbheemanagar, Bengaluru', 'Pete area, Bengaluru', 'CV Raman Nagar, Bengaluru', 'R. T. Nagar, Bengaluru']
# couldn't be obtained.
# Hence I've removed them from analysis
# The final shape of neighbourhood data is (60, 5)

# %%
neighbourhood_data.head()
# Out:
#    index   Region              Neighbourhood   Latitude  Longitude
# 0      1  Central          Domlur, Bengaluru  12.962467  77.638196
# 1      2  Central     Indiranagar, Bengaluru  12.973291  77.640467
# 2      4  Central     Malleswaram, Bengaluru  13.016341  77.558664
# 3      6  Central  Sadashivanagar, Bengaluru  13.007708  77.579589
# 4      7  Central   Seshadripuram, Bengaluru  12.993188  77.575342

# %% [markdown]
# ## Plotting the Initial Neighborhoods with Folium

# %%
location = geolocator.geocode('Bengaluru, India')
bengaluru_latitude = location.latitude
bengaluru_longitude = location.longitude
print(f"The coordinates for Bengaluru are: {bengaluru_latitude}, {bengaluru_longitude}")
# Out:
# The coordinates for Bengaluru are: 12.9791198, 77.5912997

# %%
map_bengaluru = folium.Map(location=[bengaluru_latitude, bengaluru_longitude], zoom_start=12)

for lat, lng, region, neighborhood in zip(neighbourhood_data['Latitude'], 
                                           neighbourhood_data['Longitude'], 
                                           neighbourhood_data['Region'], 
                                          neighbourhood_data['Neighbourhood']):
    label = '{}, {}'.format(neighborhood.split(',')[0], region)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_bengaluru)  
    
map_bengaluru
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Getting Venues data from the foursquare API

# %%
CLIENT_ID = 'values removed' 
CLIENT_SECRET = 'values removed' 
VERSION = '20180605' 

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: values removed
# CLIENT_SECRET:values removed

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, LIMIT = 25):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
bengaluru_venues = getNearbyVenues(names=neighbourhood_data['Neighbourhood'],
                                   latitudes=neighbourhood_data['Latitude'],
                                   longitudes=neighbourhood_data['Longitude'], 
                                   radius = 2000
                                  )
# Out:
# Domlur, Bengaluru
# Indiranagar, Bengaluru
# Malleswaram, Bengaluru
# Sadashivanagar, Bengaluru
# Seshadripuram, Bengaluru
# Shivajinagar, Bengaluru
# Ulsoor, Bengaluru
# Vasanth Nagar, Bengaluru
# Bellandur, Bengaluru
# Hoodi, Bengaluru
# Krishnarajapuram, Bengaluru
# Mahadevapura, Bengaluru
# Marathahalli, Bengaluru
# Varthur, Bengaluru
# Whitefield, Bengaluru
# Banaswadi, Bengaluru
# HBR Layout, Bengaluru
# Horamavu, Bengaluru
# Kalyan Nagar, Bengaluru
# Kammanahalli, Bengaluru
# Lingarajapuram, Bengaluru
# Ramamurthy Nagar, Bengaluru
# Hebbal, Bengaluru
# Jalahalli, Bengaluru
# Mathikere, Bengaluru
# Peenya, Bengaluru
# Vidyaranyapura, Bengaluru
# Yelahanka, Bengaluru
# Yeshwanthpur, Bengaluru
# Bommanahalli, Bengaluru
# Bommasandra, Bengaluru
# BTM Layout, Bengaluru
# Electronic City, Bengaluru
# HSR Layout, Bengaluru
# Koramangala, Bengaluru
# Madiwala, Bengaluru
# Banashankari, Bengaluru
# Basavanagudi, Bengaluru
# Girinagar, Bengaluru
# J. P. Nagar, Bengaluru
# Jayanagar, Bengaluru
# Kumaraswamy Layout, Bengaluru
# Padmanabhanagar, Bengaluru
# Uttarahalli, Bengaluru
# Anjanapura, Bengaluru
# Arekere, Bengaluru
# Begur, Bengaluru
# Gottigere, Bengaluru
# Hulimavu, Bengaluru
# Kothnur, Bengaluru
# Basaveshwaranagar, Bengaluru
# Kamakshipalya, Bengaluru
# Kengeri, Bengaluru
# Mahalakshmi Layout, Bengaluru
# Nagarbhavi, Bengaluru
# Nandini Layout, Bengaluru
# Nayandahalli, Bengaluru
# Rajajinagar, Bengaluru
# Rajarajeshwari Nagar, Bengaluru
# Vijayanagar, Bengaluru

# %%
print('Shape of dataset:', bengaluru_venues.shape)
print('Unique neighborhood venue categories in our dataset:', bengaluru_venues['Venue Category'].nunique())
# Out:
# Shape of dataset: (1297, 7)
# Unique neighborhood venue categories in our dataset: 138

# %%
bengaluru_venues.groupby('Neighborhood').count()
# Out:
#                                  Neighborhood Latitude  ...  Venue Category
# Neighborhood                                            ...
# Anjanapura, Bengaluru                                4  ...               4
# Arekere, Bengaluru                                  25  ...              25
# BTM Layout, Bengaluru                               25  ...              25
# Banashankari, Bengaluru                             25  ...              25
# Banaswadi, Bengaluru                                25  ...              25
# Basavanagudi, Bengaluru                             25  ...              25
# Basaveshwaranagar, Bengaluru                        25  ...              25
# Begur, Bengaluru                                     4  ...               4
# Bellandur, Bengaluru                                25  ...              25
# Bommanahalli, Bengaluru                             25  ...              25
# Bommasandra, Bengaluru                               7  ...               7
# Domlur, Bengaluru                                   25  ...              25
# Electronic City, Bengaluru                          25  ...              25
# Girinagar, Bengaluru                                23  ...              23
# Gottigere, Bengaluru                                 7  ...               7
# HBR Layout, Bengaluru                               25  ...              25
# HSR Layout, Bengaluru                               25  ...              25
# Hebbal, Bengaluru                                   25  ...              25
# Hoodi, Bengaluru                                    25  ...              25
# Horamavu, Bengaluru                                 20  ...              20
# Hulimavu, Bengaluru                                 25  ...              25
# Indiranagar, Bengaluru                              25  ...              25
# J. P. Nagar, Bengaluru                              25  ...              25
# Jalahalli, Bengaluru                                12  ...              12
# Jayanagar, Bengaluru                                25  ...              25
# Kalyan Nagar, Bengaluru                             25  ...              25
# Kamakshipalya, Bengaluru                            17  ...              17
# Kammanahalli, Bengaluru                             25  ...              25
# Kengeri, Bengaluru                                   9  ...               9
# Koramangala, Bengaluru                              25  ...              25
# Kothnur, Bengaluru                                  25  ...              25
# Krishnarajapuram, Bengaluru                         25  ...              25
# Kumaraswamy Layout, Bengaluru                       25  ...              25
# Lingarajapuram, Bengaluru                           25  ...              25
# Madiwala, Bengaluru                                 25  ...              25
# Mahadevapura, Bengaluru                             25  ...              25
# Mahalakshmi Layout, Bengaluru                       25  ...              25
# Malleswaram, Bengaluru                              25  ...              25
# Marathahalli, Bengaluru                             25  ...              25
# Mathikere, Bengaluru                                25  ...              25
# Nagarbhavi, Bengaluru                               12  ...              12
# Nandini Layout, Bengaluru                           25  ...              25
# Nayandahalli, Bengaluru                             25  ...              25
# Padmanabhanagar, Bengaluru                          25  ...              25
# Peenya, Bengaluru                                   21  ...              21
# Rajajinagar, Bengaluru                              25  ...              25
# Rajarajeshwari Nagar, Bengaluru                     25  ...              25
# Ramamurthy Nagar, Bengaluru                         15  ...              15
# Sadashivanagar, Bengaluru                           25  ...              25
# Seshadripuram, Bengaluru                            25  ...              25
# Shivajinagar, Bengaluru                             25  ...              25
# Ulsoor, Bengaluru                                   25  ...              25
# Uttarahalli, Bengaluru                              13  ...              13
# Varthur, Bengaluru                                   5  ...               5
# Vasanth Nagar, Bengaluru                            25  ...              25
# Vidyaranyapura, Bengaluru                            8  ...               8
# Vijayanagar, Bengaluru                              25  ...              25
# Whitefield, Bengaluru                               25  ...              25
# Yelahanka, Bengaluru                                20  ...              20
# Yeshwanthpur, Bengaluru                             25  ...              25
#
# [60 rows x 6 columns]

# %% [markdown]
# ## Analysing Each Neighborhood

# %%
bengaluru_venues = bengaluru_venues.set_index('Neighborhood')
bengaluru_onehot = pd.get_dummies(bengaluru_venues[['Venue Category']], prefix="", prefix_sep="")
bengaluru_onehot = bengaluru_onehot.drop('Neighborhood', axis = 1)
bengaluru_onehot = bengaluru_onehot.reset_index()
bengaluru_onehot.head()
# Out:
#         Neighborhood  Afghan Restaurant  ...  Women's Store  Yoga Studio
# 0  Domlur, Bengaluru                  0  ...              0            0
# 1  Domlur, Bengaluru                  0  ...              0            0
# 2  Domlur, Bengaluru                  0  ...              0            0
# 3  Domlur, Bengaluru                  0  ...              0            0
# 4  Domlur, Bengaluru                  0  ...              0            0
#
# [5 rows x 138 columns]

# %%
bengaluru_grouped = bengaluru_onehot.groupby('Neighborhood').mean().reset_index()
bengaluru_grouped
# Out:
#                        Neighborhood  ...  Yoga Studio
# 0             Anjanapura, Bengaluru  ...         0.00
# 1                Arekere, Bengaluru  ...         0.00
# 2             BTM Layout, Bengaluru  ...         0.00
# 3           Banashankari, Bengaluru  ...         0.00
# 4              Banaswadi, Bengaluru  ...         0.00
# 5           Basavanagudi, Bengaluru  ...         0.00
# 6      Basaveshwaranagar, Bengaluru  ...         0.00
# 7                  Begur, Bengaluru  ...         0.00
# 8              Bellandur, Bengaluru  ...         0.00
# 9           Bommanahalli, Bengaluru  ...         0.00
# 10           Bommasandra, Bengaluru  ...         0.00
# 11                Domlur, Bengaluru  ...         0.00
# 12       Electronic City, Bengaluru  ...         0.00
# 13             Girinagar, Bengaluru  ...         0.00
# 14             Gottigere, Bengaluru  ...         0.00
# 15            HBR Layout, Bengaluru  ...         0.00
# 16            HSR Layout, Bengaluru  ...         0.00
# 17                Hebbal, Bengaluru  ...         0.00
# 18                 Hoodi, Bengaluru  ...         0.00
# 19              Horamavu, Bengaluru  ...         0.00
# 20              Hulimavu, Bengaluru  ...         0.00
# 21           Indiranagar, Bengaluru  ...         0.00
# 22           J. P. Nagar, Bengaluru  ...         0.00
# 23             Jalahalli, Bengaluru  ...         0.00
# 24             Jayanagar, Bengaluru  ...         0.00
# 25          Kalyan Nagar, Bengaluru  ...         0.00
# 26         Kamakshipalya, Bengaluru  ...         0.00
# 27          Kammanahalli, Bengaluru  ...         0.00
# 28               Kengeri, Bengaluru  ...         0.00
# 29           Koramangala, Bengaluru  ...         0.04
# 30               Kothnur, Bengaluru  ...         0.00
# 31      Krishnarajapuram, Bengaluru  ...         0.00
# 32    Kumaraswamy Layout, Bengaluru  ...         0.00
# 33        Lingarajapuram, Bengaluru  ...         0.00
# 34              Madiwala, Bengaluru  ...         0.04
# 35          Mahadevapura, Bengaluru  ...         0.00
# 36    Mahalakshmi Layout, Bengaluru  ...         0.00
# 37           Malleswaram, Bengaluru  ...         0.00
# 38          Marathahalli, Bengaluru  ...         0.00
# 39             Mathikere, Bengaluru  ...         0.00
# 40            Nagarbhavi, Bengaluru  ...         0.00
# 41        Nandini Layout, Bengaluru  ...         0.00
# 42          Nayandahalli, Bengaluru  ...         0.00
# 43       Padmanabhanagar, Bengaluru  ...         0.00
# 44                Peenya, Bengaluru  ...         0.00
# 45           Rajajinagar, Bengaluru  ...         0.00
# 46  Rajarajeshwari Nagar, Bengaluru  ...         0.00
# 47      Ramamurthy Nagar, Bengaluru  ...         0.00
# 48        Sadashivanagar, Bengaluru  ...         0.00
# 49         Seshadripuram, Bengaluru  ...         0.00
# 50          Shivajinagar, Bengaluru  ...         0.00
# 51                Ulsoor, Bengaluru  ...         0.00
# 52           Uttarahalli, Bengaluru  ...         0.00
# 53               Varthur, Bengaluru  ...         0.00
# 54         Vasanth Nagar, Bengaluru  ...         0.00
# 55        Vidyaranyapura, Bengaluru  ...         0.00
# 56           Vijayanagar, Bengaluru  ...         0.00
# 57            Whitefield, Bengaluru  ...         0.00
# 58             Yelahanka, Bengaluru  ...         0.00
# 59          Yeshwanthpur, Bengaluru  ...         0.00
#
# [60 rows x 138 columns]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = bengaluru_grouped['Neighborhood']

for ind in np.arange(bengaluru_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(bengaluru_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#               Neighborhood  ...    10th Most Common Venue
# 0    Anjanapura, Bengaluru  ...       Dumpling Restaurant
# 1       Arekere, Bengaluru  ...     Rajasthani Restaurant
# 2    BTM Layout, Bengaluru  ...  Mediterranean Restaurant
# 3  Banashankari, Bengaluru  ...                      Café
# 4     Banaswadi, Bengaluru  ...        Falafel Restaurant
#
# [5 rows x 11 columns]

# %% [markdown]
# ## Clustering with K means unsupervised learning

# %%
kclusters = 5

bengaluru_grouped_clustering = bengaluru_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(bengaluru_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 2, 2, 2, 1, 1, 1, 1, 3, 2], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

bengaluru_merged = neighbourhood_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
bengaluru_merged = bengaluru_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

bengaluru_merged.head() # check the last columns!
# Out:
#    index   Region  ... 9th Most Common Venue  10th Most Common Venue
# 0      1  Central  ...                 Hotel          Chocolate Shop
# 1      2  Central  ...                Lounge       German Restaurant
# 2      4  Central  ...                   Pub           Movie Theater
# 3      6  Central  ...      Department Store                     Pub
# 4      7  Central  ...    Chinese Restaurant                     Pub
#
# [5 rows x 16 columns]

# %% [markdown]
# ## Map with Clustered Neighborhoods

# %%
# create map
map_clusters = folium.Map(location=[bengaluru_latitude, bengaluru_longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(bengaluru_merged['Latitude'], bengaluru_merged['Longitude'], bengaluru_merged['Neighbourhood'], 
                                  bengaluru_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Results

# %% [markdown]
# ### Cluster 0

# %%
names = [name[0] for name in bengaluru_merged["Neighbourhood"].str.split(',')]
bengaluru_merged['Neighbourhood'] = names
columns = ["Region","Neighbourhood","1st Most Common Venue", "2nd Most Common Venue", "3rd Most Common Venue"]
bengaluru_merged[bengaluru_merged['Cluster Labels'] == 0][columns]
# Out:
#               Region  ... 3rd Most Common Venue
# 13           Eastern  ...                Bakery
# 27          Northern  ...                  Lake
# 34     South-Eastern  ...                Bakery
# 35     South-Eastern  ...        Breakfast Spot
# 38          Southern  ...  Fast Food Restaurant
# 49  Southern suburbs  ...      Department Store
# 54           Western  ...           Supermarket
# 58           Western  ...                Arcade
#
# [8 rows x 5 columns]

# %% [markdown]
# ### Cluster 1

# %%
bengaluru_merged[bengaluru_merged['Cluster Labels'] == 1][columns]
# Out:
#               Region  ...          3rd Most Common Venue
# 12           Eastern  ...  Vegetarian / Vegan Restaurant
# 15     North-Eastern  ...              Korean Restaurant
# 16     North-Eastern  ...           Fast Food Restaurant
# 17     North-Eastern  ...                    Coffee Shop
# 21     North-Eastern  ...                    Supermarket
# 22          Northern  ...  Vegetarian / Vegan Restaurant
# 23          Northern  ...                         Bakery
# 37          Southern  ...                 Sandwich Place
# 39          Southern  ...          Performing Arts Venue
# 40          Southern  ...                 Sandwich Place
# 42          Southern  ...                    Pizza Place
# 46  Southern suburbs  ...        South Indian Restaurant
# 47  Southern suburbs  ...             Italian Restaurant
# 50           Western  ...                 Ice Cream Shop
# 51           Western  ...           Fast Food Restaurant
# 52           Western  ...                 Ice Cream Shop
# 57           Western  ...                         Bakery
# 59           Western  ...                         Bakery
#
# [18 rows x 5 columns]

# %% [markdown]
# ### Cluster 2

# %%
bengaluru_merged[bengaluru_merged['Cluster Labels'] == 2][columns]
# Out:
#               Region  ... 3rd Most Common Venue
# 0            Central  ...                   Pub
# 1            Central  ...      Asian Restaurant
# 3            Central  ...                 Hotel
# 4            Central  ...                 Hotel
# 5            Central  ...                   Pub
# 6            Central  ...               Brewery
# 7            Central  ...    Chinese Restaurant
# 9            Eastern  ...               Brewery
# 14           Eastern  ...     Indian Restaurant
# 18     North-Eastern  ...     Indian Restaurant
# 19     North-Eastern  ...     Indian Restaurant
# 20     North-Eastern  ...         Shopping Mall
# 24          Northern  ...                  Park
# 25          Northern  ...                   Spa
# 26          Northern  ...     Indian Restaurant
# 29     South-Eastern  ...                  Café
# 30     South-Eastern  ...   Sporting Goods Shop
# 31     South-Eastern  ...                Bakery
# 33     South-Eastern  ...    Punjabi Restaurant
# 36          Southern  ...  Fast Food Restaurant
# 41          Southern  ...                  Café
# 43          Southern  ...                  Café
# 45  Southern suburbs  ...     Indian Restaurant
# 48  Southern suburbs  ...             Multiplex
# 56           Western  ...        Ice Cream Shop
#
# [25 rows x 5 columns]

# %% [markdown]
# ### Cluster 3

# %%
bengaluru_merged[bengaluru_merged['Cluster Labels'] == 3][columns]
# Out:
#            Region  ... 3rd Most Common Venue
# 2         Central  ...     Indian Restaurant
# 8         Eastern  ...    Italian Restaurant
# 10        Eastern  ...            Donut Shop
# 11        Eastern  ...            Donut Shop
# 28       Northern  ...           Coffee Shop
# 32  South-Eastern  ...    Italian Restaurant
# 53        Western  ...        Clothing Store
# 55        Western  ...         Bowling Alley
#
# [8 rows x 5 columns]

# %% [markdown]
# ### Cluster 4

# %%
bengaluru_merged[bengaluru_merged['Cluster Labels'] == 4][columns]
# Out:
#               Region Neighbourhood  ... 2nd Most Common Venue 3rd Most Common Venue
# 44  Southern suburbs    Anjanapura  ...                Lounge         Train Station
#
# [1 rows x 5 columns]
